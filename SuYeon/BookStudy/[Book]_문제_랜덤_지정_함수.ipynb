# %% [markdown]
# <a href="https://colab.research.google.com/github/songmac/2023-Algorithm-Study-purDA/blob/main/%5BBook%5D_%EB%AC%B8%EC%A0%9C_%EB%9E%9C%EB%8D%A4_%EC%A7%80%EC%A0%95_%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#자료구조 (문제, 멤버) 랜덤 지정 함수

import random

def BookStudy(prob_num) :

  prob_extract = random.sample(range(1,prob_num),7) #문제 7개 랜덤 뽑기
  members = ['가희', '수연', '유미', '소희', '지우', '하영', '윤선']
  prob_mem_set = list(zip(prob_extract, members))

  for show in prob_mem_set :
    print(show)

  return show

prob_num= int(input('문제 수를 입력하세요: '))
result = BookStudy(prob_num)
print(result)
# Out:
# 문제 수를 입력하세요: 10
# (9, '가희')
# (5, '수연')
# (7, '유미')
# (3, '소희')
# (8, '지우')
# (2, '하영')
# (1, '윤선')
# (1, '윤선')
